# %%
print('hello')
# Out:
# hello

# %%
import turtle
turtle.forward(100)

# %%
turtle.done()

# %% [markdown]
# # Title
# ## Subtitle
#
# Mathematical typesetting example:
#
# $$e^{i\pi} + 1 = 0$$
# $$ \frac{\pi^2}{6} = \sum_{i=1}^{\infty}\frac{1}{i^2}= \frac{1}{1^2} + \frac{1}{2^2} + \frac{1}{3^2} + \cdots$$

# %%
s = 0
for i in range(1, 1000):
    s += 1.0 / i**2
print s
# Out:
# 1.64393356668

# %%
import math
print math.pi**2/6
# Out:
# 1.64493406685

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pi/3
# Out:
# 1.0471975511965976

# %%
def partial_sum(n):
    s = 0
    for i in range(1, n):
        s += 1.0 / i**2
    return s

# %%
partial_sum(5)
# Out:
# 1.4236111111111112

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
results = [partial_sum(n) for n in range(1, 100)]
plt.plot(results)

# %% [markdown]
# # Wow
# But, now what?
#
# This is normal text, styled using *Markdown*.  For example, in Markdown, web links look like this:
#
# [Here is a web link](http://www.bbc.co.uk)
#
# ### Lists
#  Here is how to do a list in markdown:
#  - one
#  - two
#  - three
#
#  And a numbered list:
#
# 1. blah
#    1. first
#    2. second
#    3. turd :-)
#       - this
#       - that
#       - the other
# 2. blah
# 3. blah
# 4. blah
#
#
# ### Styling
# - _this_
# - *that*
# - **what bout this?**
#
# `back ticks`
#
#
# ```python
# import turtle
# print('hello')
# ```
#
# That (above) is a code block.
#
# Here is an example program in the C programming language:
#
# ```C
# #include <stdio.h>
#
# int main(char **args) {
#    printf("Hello, World!\n");
#
#    return 0;
# }
# ```

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
with plt.xkcd():
    plt.plot(range(100))

# %%
"""
================
PathPatch object
================

This example shows how to create `Path`\s and `PathPatch` objects through
Matplotlib's API.
"""
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

with plt.xkcd():
    fig, ax = plt.subplots()

    Path = mpath.Path
    path_data = [
        (Path.MOVETO, (1.58, -2.57)),
        (Path.CURVE4, (0.35, -1.1)),
        (Path.CURVE4, (-1.75, 2.0)),
        (Path.CURVE4, (0.375, 2.0)),
        (Path.LINETO, (0.85, 1.15)),
        (Path.CURVE4, (2.2, 3.2)),
        (Path.CURVE4, (3, 0.05)),
        (Path.CURVE4, (2.0, -0.5)),
        (Path.CLOSEPOLY, (1.58, -2.57)),
        ]
    codes, verts = zip(*path_data)
    path = mpath.Path(verts, codes)
    patch = mpatches.PathPatch(path, facecolor='r', alpha=0.5)
    ax.add_patch(patch)

    # plot control points and connecting lines
    x, y = zip(*path.vertices)
    line, = ax.plot(x, y, 'go-')

    ax.grid()
    ax.axis('equal')
    plt.show()

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

styles = mpatches.ArrowStyle.get_styles()

ncol = 2
nrow = (len(styles) + 1) // ncol
figheight = (nrow + 0.5)
fig1 = plt.figure(1, (4.*ncol/1.5, figheight/1.5))
fontsize = 0.2 * 70


ax = fig1.add_axes([0, 0, 1, 1], frameon=False, aspect=1.)

ax.set_xlim(0, 4*ncol)
ax.set_ylim(0, figheight)


def to_texstring(s):
    s = s.replace("<", r"$<$")
    s = s.replace(">", r"$>$")
    s = s.replace("|", r"$|$")
    return s

for i, (stylename, styleclass) in enumerate(sorted(styles.items())):
    x = 3.2 + (i//nrow)*4
    y = (figheight - 0.7 - i % nrow)  # /figheight
    p = mpatches.Circle((x, y), 0.2)
    ax.add_patch(p)

    ax.annotate(to_texstring(stylename), (x, y),
                (x - 1.2, y),
                #xycoords="figure fraction", textcoords="figure fraction",
                ha="right", va="center",
                size=fontsize,
                arrowprops=dict(arrowstyle=stylename,
                                patchB=p,
                                shrinkA=5,
                                shrinkB=5,
                                fc="k", ec="k",
                                connectionstyle="arc3,rad=-0.05",
                                ),
                bbox=dict(boxstyle="square", fc="w"))

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)


plt.draw()
plt.show()

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

styles = mpatches.ArrowStyle.get_styles()

with plt.xkcd():
    ncol = 2
    nrow = (len(styles) + 1) // ncol
    figheight = (nrow + 0.5)
    fig1 = plt.figure(1, (4.*ncol/1.5, figheight/1.5))
    fontsize = 0.2 * 70


    ax = fig1.add_axes([0, 0, 1, 1], frameon=False, aspect=1.)

    ax.set_xlim(0, 4*ncol)
    ax.set_ylim(0, figheight)


    def to_texstring(s):
        s = s.replace("<", r"$<$")
        s = s.replace(">", r"$>$")
        s = s.replace("|", r"$|$")
        return s

    for i, (stylename, styleclass) in enumerate(sorted(styles.items())):
        x = 3.2 + (i//nrow)*4
        y = (figheight - 0.7 - i % nrow)  # /figheight
        p = mpatches.Circle((x, y), 0.2)
        ax.add_patch(p)

        ax.annotate(to_texstring(stylename), (x, y),
                    (x - 1.2, y),
                    #xycoords="figure fraction", textcoords="figure fraction",
                    ha="right", va="center",
                    size=fontsize,
                    arrowprops=dict(arrowstyle=stylename,
                                    patchB=p,
                                    shrinkA=5,
                                    shrinkB=5,
                                    fc="k", ec="k",
                                    connectionstyle="arc3,rad=-0.05",
                                    ),
                    bbox=dict(boxstyle="square", fc="w"))

    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)


    plt.draw()
    plt.show()
